# %%
import requests

# %%
# 基本code

# %%
r = requests.get("目標網址")

# %%
r = requests.get("https://www.dcard.tw/_api/forums/pet/posts?popular=true")
response = r.text

# %%
r.text
# Out:
# '[{"id":233287261,"title":"玩一天的麻糬","excerpt":"帶去學校一天，好像對他來說太累了，一回同學家，馬上昏睡🤣，死不趴好睡餒，一定要往後仰🤣，要睡不睡的臉🤣，整個往後倒是怎樣🤣，辛苦麻糬了，下次帶你去上班就好","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"7ee21581-1307-4ba9-b9dc-82028bdcca49","replyId":null,"createdAt":"2020-03-18T04:29:18.050Z","updatedAt":"2020-03-18T04:36:57.968Z","commentCount":17,"likeCount":245,"withNickname":true,"tags":[],"topics":["麻糬","柴犬","寵物","狗"],"meta":{"layout":"classic"},"forumName":"寵物","forumAlias":"pet","gender":"F","school":"Yaping","department":"jyp1011","replyTitle":null,"mediaMeta":[{"id":"7e9131dd-3c47-46ce-8c93-87ce65fd08b0","url":"https://megapx-assets.dcard.tw/images/ba44252c-3140-4844-a008-11e44de8408c/320.jpeg","normalizedUrl":"https://megapx-assets.dcard.tw/images/ba44252c-3140-4844-a008-11e44de8408c/320.jpeg","thumbnail":"https://megapx-assets.dcard.tw/images/ba44252c-3140-4844-a008-11e44de8408c/320.jpeg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-03-18T04:29:18.050Z"
# ...

# %%
# 得到JSON格式的字串

# %%
import json

# %%
data = json.loads(response) #利用json解析網頁內容

# %%
for d in data:
    print(d['title']) #取出每篇文章的標題
# Out:
# 玩一天的麻糬
# 🦎我的小守宮🦎
# 「⚠️毛小孩家長注意⚠️」
# 去魚X魚泰山店寵物美容卻被弄到骨折
# （更)台中黃金獵犬天堂💗
# 求解 怎麼讓貓不把我的鎖骨當床
# 師大虐狗朱女領養貓？
# 浪貓 #
# 肥包🐈
# 憨吉的各種表情包
# 如何陪伴你的狗成長? 2.做個令牠敬佩的領導
# 是時候了嗎？
# 想請教自家狗狗品種
# 犬種介紹特輯15 小鋼炮 約克夏梗~
# 跌倒的蚊子(・∀・)
# 我媽說要戴口罩才能一起玩!
# #電繪 寵物畫像
# 當你不再家，家裡的寵物在...
# 求主子照片多一點
# 越來越有個性的肥弟
# 是黃金獵犬 不是拉不拉多啦🐾
# 嗚嗚對不起我不該偷拍你的
# 協尋主人
# #狗 標準型貴賓的巨變日記 03
# 不牽繩卻責怪騎士的不知檢討恐龍家長
# 素顏
# 小弟-提摩
# 打瞌睡成上癮
# 兔子的舌頭有多大👅
# 沉重的愛
# 喜歡玩海盜船的貓
